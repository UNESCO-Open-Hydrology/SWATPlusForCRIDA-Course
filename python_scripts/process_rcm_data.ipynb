# %%
'''
This notebook is used to process RCM data in NETCDF format

What it does:
- Clip to area of interest
- Reproject data to a regular geographical 2D grid
- Convert units for SWAT+

Data details:
    RCM from 5 RCMs CORDEX-SAM44
    For baseline period and future projection[rcp 4.5 & rcp 8.5] (1981-2005 & 2076-2100)
    
** Notes:
- This script will deal with precipitation and temperature data, but it can be adjusted for other variables
- SWAT+ Can also use Relative Humidity, Solar Radiation, and Wind Speed if Penmann-Monteith equation is used to calculate PET
- For this model, the Hargreaves method was chosen to calculate PET
- Orginal RCM NETCDF Files are stored in a Pickle - This is done to save space, however, you may need to adapt your code to read the NETCDF files directly from a folder
- Data from e.g., ISIMIP, does not require reprojection, so the script can be edited to skip that step


'''
import xarray as xr
import os
import rioxarray
import numpy as np
from pyproj import Proj, transform,CRS, Transformer
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
from scipy.interpolate import griddata
import pickle

os.chdir('..') # Changing to main SWATPlusForCRIDA

# %%
# Defining Models, experiments, variables and periods
# This will be useful to mantain order, read and save files

model_list=["SAM_44_RCA4_EC_EARTH",
            "SAM_44_RCA4_GFDL",
            "SAM_44_RCA4_HadGEM2",
            "SAM_44_RCA4_IPSL",
            "SAM_44_RCA4_MIROC5"]

experiment_list=["historical",
                 "rcp45",
                 "rcp85"]

period_list=["1981_2005","2076_2100"]

variable_list=["pr",
               "tasmax",
               "tasmin"]

# Define area of interest
# This area covers the part country of Bolivia, where the case Study is located
lat_min=-20
lat_max=-14
lon_min=-70
lon_max=-67

# %%
# Open pickles, loop through dictionaries, clip, reproject and save into new netcdfs
original_data_path = "data/CaseStudy/data/climate_data/RCM/original"
data_path = "data/CaseStudy/data/climate_data/RCM"
file_ext = ".pkl"

for experiment in experiment_list:
    print(f"\n🔷 Starting experiment: {experiment}")
    file = f"{original_data_path}/{experiment}{file_ext}"
    with open(file, "rb") as f:
        print(f"📂 Loaded pickle: {file}")
        loaded_netcdf_dict = pickle.load(f)

        for model in model_list:
            print(f"  📦 Processing model: {model}")
            for variable in variable_list:
                print(f"    🔍 Variable: {variable} – Computing and clipping...")
                ds = loaded_netcdf_dict[model][variable].compute()
                ds = ds.where(
                    (ds['lat'] >= lat_min) & (ds['lat'] <= lat_max) &
                    (ds['lon'] >= lon_min) & (ds['lon'] <= lon_max),
                    drop=True
                )

                lat = ds["lat"].values
                lon = ds["lon"].values
                time = ds["time"].values

                lat_n = np.linspace(lat.min(), lat.max(), num=lat.shape[0])
                lon_n = np.linspace(lon.min(), lon.max(), num=lon.shape[1])
                lon_n_gr, lat_n_gr = np.meshgrid(lon_n, lat_n)

                data_carrier = np.empty((len(time), len(lat_n), len(lon_n)))

                print(f"    📈 Reprojecting timeseries: {len(time)} timesteps")
                for t in range(len(time)):
                    data_on_t = ds[variable].isel(time=t).values
                    var_int = griddata(
                        (lon.flatten(), lat.flatten()),
                        data_on_t.flatten(),
                        (lon_n_gr, lat_n_gr),
                        method='linear'
                    )
                    data_carrier[t, :, :] = var_int

                ds_new = xr.Dataset(
                    {variable: (['time', 'lat', 'lon'], data_carrier)},
                    coords={'time': time, 'lat': lat_n, 'lon': lon_n}
                )

                save_folder = f"{data_path}/repr/{experiment}/{model}"
                os.makedirs(save_folder, exist_ok=True)
                new_file = f"{save_folder}/{model}_{variable}_{experiment}.nc"
                ds_new.to_netcdf(new_file)
                print(f"    ✅ Saved: {new_file}")

    print(f"✔️ Finished experiment: {experiment}")
# Out:
# 🔷 Starting experiment: historical
# 📂 Loaded pickle: data/CaseStudy/data/climate_data/RCM/original/historical.pkl
#   📦 Processing model: SAM_44_RCA4_EC_EARTH
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10958 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_EC_EARTH/SAM_44_RCA4_EC_EARTH_pr_historical.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10958 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_EC_EARTH/SAM_44_RCA4_EC_EARTH_tasmax_historical.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10958 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_EC_EARTH/SAM_44_RCA4_EC_EARTH_tasmin_historical.nc
#   📦 Processing model: SAM_44_RCA4_GFDL
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_GFDL/SAM_44_RCA4_GFDL_pr_historical.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_GFDL/SAM_44_RCA4_GFDL_tasmax_historical.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_GFDL/SAM_44_RCA4_GFDL_tasmin_historical.nc
#   📦 Processing model: SAM_44_RCA4_HadGEM2
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10800 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_HadGEM2/SAM_44_RCA4_HadGEM2_pr_historical.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10800 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_HadGEM2/SAM_44_RCA4_HadGEM2_tasmax_historical.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10800 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_HadGEM2/SAM_44_RCA4_HadGEM2_tasmin_historical.nc
#   📦 Processing model: SAM_44_RCA4_IPSL
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_IPSL/SAM_44_RCA4_IPSL_pr_historical.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_IPSL/SAM_44_RCA4_IPSL_tasmax_historical.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_IPSL/SAM_44_RCA4_IPSL_tasmin_historical.nc
#   📦 Processing model: SAM_44_RCA4_MIROC5
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_MIROC5/SAM_44_RCA4_MIROC5_pr_historical.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_MIROC5/SAM_44_RCA4_MIROC5_tasmax_historical.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/historical/SAM_44_RCA4_MIROC5/SAM_44_RCA4_MIROC5_tasmin_historical.nc
# ✔️ Finished experiment: historical
#
# 🔷 Starting experiment: rcp45
# 📂 Loaded pickle: data/CaseStudy/data/climate_data/RCM/original/rcp45.pkl
#   📦 Processing model: SAM_44_RCA4_EC_EARTH
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10957 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_EC_EARTH/SAM_44_RCA4_EC_EARTH_pr_rcp45.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10957 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_EC_EARTH/SAM_44_RCA4_EC_EARTH_tasmax_rcp45.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10957 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_EC_EARTH/SAM_44_RCA4_EC_EARTH_tasmin_rcp45.nc
#   📦 Processing model: SAM_44_RCA4_GFDL
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_GFDL/SAM_44_RCA4_GFDL_pr_rcp45.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_GFDL/SAM_44_RCA4_GFDL_tasmax_rcp45.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_GFDL/SAM_44_RCA4_GFDL_tasmin_rcp45.nc
#   📦 Processing model: SAM_44_RCA4_HadGEM2
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10410 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_HadGEM2/SAM_44_RCA4_HadGEM2_pr_rcp45.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10410 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_HadGEM2/SAM_44_RCA4_HadGEM2_tasmax_rcp45.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10410 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_HadGEM2/SAM_44_RCA4_HadGEM2_tasmin_rcp45.nc
#   📦 Processing model: SAM_44_RCA4_IPSL
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_IPSL/SAM_44_RCA4_IPSL_pr_rcp45.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_IPSL/SAM_44_RCA4_IPSL_tasmax_rcp45.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_IPSL/SAM_44_RCA4_IPSL_tasmin_rcp45.nc
#   📦 Processing model: SAM_44_RCA4_MIROC5
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_MIROC5/SAM_44_RCA4_MIROC5_pr_rcp45.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_MIROC5/SAM_44_RCA4_MIROC5_tasmax_rcp45.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp45/SAM_44_RCA4_MIROC5/SAM_44_RCA4_MIROC5_tasmin_rcp45.nc
# ✔️ Finished experiment: rcp45
#
# 🔷 Starting experiment: rcp85
# 📂 Loaded pickle: data/CaseStudy/data/climate_data/RCM/original/rcp85.pkl
#   📦 Processing model: SAM_44_RCA4_EC_EARTH
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10957 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_EC_EARTH/SAM_44_RCA4_EC_EARTH_pr_rcp85.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10957 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_EC_EARTH/SAM_44_RCA4_EC_EARTH_tasmax_rcp85.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10957 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_EC_EARTH/SAM_44_RCA4_EC_EARTH_tasmin_rcp85.nc
#   📦 Processing model: SAM_44_RCA4_GFDL
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_GFDL/SAM_44_RCA4_GFDL_pr_rcp85.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_GFDL/SAM_44_RCA4_GFDL_tasmax_rcp85.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_GFDL/SAM_44_RCA4_GFDL_tasmin_rcp85.nc
#   📦 Processing model: SAM_44_RCA4_HadGEM2
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10440 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_HadGEM2/SAM_44_RCA4_HadGEM2_pr_rcp85.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10440 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_HadGEM2/SAM_44_RCA4_HadGEM2_tasmax_rcp85.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10440 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_HadGEM2/SAM_44_RCA4_HadGEM2_tasmin_rcp85.nc
#   📦 Processing model: SAM_44_RCA4_IPSL
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_IPSL/SAM_44_RCA4_IPSL_pr_rcp85.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_IPSL/SAM_44_RCA4_IPSL_tasmax_rcp85.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_IPSL/SAM_44_RCA4_IPSL_tasmin_rcp85.nc
#   📦 Processing model: SAM_44_RCA4_MIROC5
#     🔍 Variable: pr – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_MIROC5/SAM_44_RCA4_MIROC5_pr_rcp85.nc
#     🔍 Variable: tasmax – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_MIROC5/SAM_44_RCA4_MIROC5_tasmax_rcp85.nc
#     🔍 Variable: tasmin – Computing and clipping...
#     📈 Reprojecting timeseries: 10950 timesteps
#     ✅ Saved: data/CaseStudy/data/climate_data/RCM/repr/rcp85/SAM_44_RCA4_MIROC5/SAM_44_RCA4_MIROC5_tasmin_rcp85.nc
# ✔️ Finished experiment: rcp85

# %%
# Plot check with last processed netcdf
'''
This block can be updated to read the already processed data and plot any variable from any model and experiment
Just read the NETCDF files produced above
'''
plt.figure(figsize=(7, 7))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_global()
ax.set_extent([-74, -56, -26, -5], crs=ccrs.PlateCarree())
ax.add_feature(cartopy.feature.OCEAN, color='white', zorder=0)
ax.gridlines(draw_labels=True, linewidth=0.5, color='gray',
                 xlocs=range(-180,180,2), ylocs=range(-90,90,2))
ax.coastlines(resolution='50m', linewidth=0.3, color='black')
(ds_new[variable].mean(dim="time")-273.15).plot(ax=ax,cmap="RdBu_r",    cbar_kwargs={
                                                                                'shrink': 0.4,         # Adjust size of the colorbar
                                                                                'aspect': 15,          # Make it thinner or thicker
                                                                                'label': variable,     # Optional label
                                                                                'pad': 0.08            # Space between plot and colorbar
                                                                            },
                                                vmin=0,vmax=25)

ax.add_feature(cartopy.feature.BORDERS, color='black',zorder=1,
                   linewidth=0.5, edgecolor='black')
ax.set_title(f"Mean daily {variable} - {model} - {experiment} - {period_list[1]}")
# Out:
# c:\Users\joset\anaconda3\envs\jopato_env\Lib\site-packages\cartopy\mpl\feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# Text(0.5, 1.0, 'Mean daily tasmin - SAM_44_RCA4_MIROC5 - rcp85 - 2076_2100')
